# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhias-a11y/colab/blob/main/lab06_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1

# %%
import matplotlib.pyplot as plt

x= range(0, 10)
y = [2*value for value in x]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x= range(0, 10)
y = [2*value for value in x]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x= range(0, 10)
y = [2*value for value in x]

def is_in_interval(number, minimum, maximum):
  return minimum<number<=maximum

plt.plot(x,y)
where = [is_in_interval(value, 2,6) for value in x]
plt.fill_between(x,y, where=where)
plt.show()

# %%
import matplotlib.pyplot as plt
x= range(0, 10)
y = [2*value for value in x]

plt.scatter(x,y)
plt.plot(x,y)
plt.fill_between(x,y, where=where)

plt.xlabel('values between zero and ten')
plt.ylabel("Twice the values of x")
plt.show()

# %% [markdown]
# What basic Matplotlib plots will we be using?
#
# This lab uses the scatter, plot (line graph), fill functions of the Matplotlib library. We also were able to superimpose the line graph on top of the scatter dots to create a doubled effect plot.
