# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhias-a11y/colab/blob/main/lab13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ch 11: Data Science in Other Languages

# %%
import pandas as pd
players=pd.read_csv('players.csv', encoding = 'ISO-8859-1')
games=pd.read_csv('games.csv', encoding = 'ISO-8859-1')
shots=pd.read_csv('shots.csv', encoding = 'ISO-8859-1')

# %%
print(players.head())
print(games.head())
print(shots.head())
# Out:
#    playerID            name
# 0       560   Sergio Romero
# 1       557  Matteo Darmian
# 2       548     Daley Blind
# 3       628  Chris Smalling
# 4      1006       Luke Shaw
#    gameID  leagueID  season                 date  homeTeamID  awayTeamID  \
# 0      81         1    2015  2015-08-08 15:45:00          89          82
# 1      82         1    2015  2015-08-08 18:00:00          73          71
# 2      83         1    2015  2015-08-08 18:00:00          72          90
# 3      84         1    2015  2015-08-08 18:00:00          75          77
# 4      85         1    2015  2015-08-08 18:00:00          79          78
#
#    homeGoals  awayGoals  homeProbability  drawProbability  ...   PSA   WHH  \
# 0          1          0           0.2843           0.3999  ...  5.90  1.62
# 1          0          1           0.3574           0.3500  ...  4.27  1.91
# 2          2          2           0.2988           0.4337  ...  5.62  1.73
# ...

# %%
print(players.loc[7,'name'])
# Out:
# Juan Mata

# %%
import sqlite3
conn = sqlite3.connect("soccer.db")
curr = conn.cursor()

# %%
players.to_sql('playertable', conn, if_exists='replace', index = False)
# Out:
# 7659

# %%
curr.execute('''
SELECT * FROM playertable
 ''')

# %%
for row in curr.fetchall():
 print(row)
# Out:
# (560, 'Sergio Romero')
# (557, 'Matteo Darmian')
# (548, 'Daley Blind')
# (628, 'Chris Smalling')
# (1006, 'Luke Shaw')
# (551, 'Morgan Schneiderlin')
# (654, 'Michael Carrick')
# (554, 'Juan Mata')
# (555, 'Memphis Depay')
# (631, 'Ashley Young')
# (629, 'Wayne Rooney')
# (552, 'Ander Herrera')
# (627, 'Antonio Valencia')
# (907, 'Bastian Schweinsteiger')
# (651, 'Michel Vorm')
# (638, 'Kyle Walker')
# (639, 'Toby Alderweireld')
# (640, 'Jan Vertonghen')
# (660, 'Ben Davies')
# (914, 'Nabil Bentaleb')
# (643, 'Eric Dier')
# (642, 'Mousa Dembélé')
# (646, 'Christian Eriksen')
# (648, 'Nacer Chadli')
# (647, 'Harry Kane')
# (649, 'Ryan Mason')
# (644, 'Erik Lamela')
# (645, 'Dele Alli')
# (455, 'Artur Boruc')
# (456, 'Simon Francis')
# (458, 'Steve Cook')
# (457, 'Tommy Elphick')
# (459, 'Charlie Daniels')
# (461, 'Matt Ritchie')
# (460, 'Andrew Surman')
# (462, 'Dan Gosling')
# (466, 'Marc Pugh')
# (465, 'Joshua King')
# (468, 'Callum Wilson')
# (957, 'Yann Kermorgant')
# ...

# %%
curr.execute('''
SELECT * FROM playertable LIMIT 5
 ''')
for row in curr.fetchall():
 print (row)
# Out:
# (560, 'Sergio Romero')
# (557, 'Matteo Darmian')
# (548, 'Daley Blind')
# (628, 'Chris Smalling')
# (1006, 'Luke Shaw')

# %%
curr.execute('''
SELECT * FROM playertable WHERE playerID=554
 ''')
for row in curr.fetchall():
 print (row)
# Out:
# (554, 'Juan Mata')

# %%
curr.execute('''
SELECT playerID FROM playertable WHERE name="Juan Mata"
 ''')
for row in curr.fetchall():
 print (row)
# Out:
# (554,)

# %%
curr.execute('''
SELECT * FROM playertable WHERE playerID>100 AND playerID<200
 ''')
for row in curr.fetchall():
 print (row)
# Out:
# (191, 'Chicharito')
# (162, 'Timm Klose')
# (163, 'René Adler')
# (175, 'Dennis Diekmeier')
# (165, 'Emir Spahic')
# (167, 'Matthias Ostrzolek')
# (168, 'Gideon Jung')
# (169, 'Lewis Holtby')
# (171, 'Michael Gregoritsch')
# (176, 'Sven Schipplock')
# (172, 'Ivo Ilicevic')
# (173, 'Pierre-Michel Lasogga')
# (177, 'Marcelo Díaz')
# (181, 'Bernd Leno')
# (182, 'Roberto Hilbert')
# (197, 'Kyriakos Papadopoulos')
# (183, 'Jonathan Tah')
# (185, 'Wendell')
# (187, 'Christoph Kramer')
# (186, 'Karim Bellarabi')
# (189, 'Hakan Calhanoglu')
# (190, 'Stefan Kießling')
# (195, 'André Ramalho')
# (194, 'Admir Mehmedi')
# (109, 'Felix Wiedwald')
# (110, 'Theodor Gebre Selassie')
# (123, 'Assani Lukimya')
# (111, 'Jannik Vestergaard')
# (114, 'Philipp Bargfrede')
# (117, 'Clemens Fritz')
# (115, 'Fin Bartels')
# (119, 'Anthony Ujah')
# (118, 'Levin Öztunali')
# (116, 'Florian Grillitsch')
# (112, 'Alejandro Gálvez')
# (152, 'Julian Draxler')
# (108, 'Manuel Schmiedebach')
# ...

# %%
curr.execute('''
SELECT * FROM playertable WHERE name LIKE "Juan M%"
 ''')
for row in curr.fetchall():
 print (row)
# Out:
# (554, 'Juan Mata')
# (2585, 'Juan Muñiz')
# (2067, 'Juan Muñoz')
# (4820, 'Juan Manuel Falcón')
# (7095, 'Juan Musso')
# (5009, 'Juan Manuel Valencia')
# (7286, 'Juan Miranda')

# %%
games=pd.read_csv('games.csv', encoding = 'ISO-8859-1')
games.to_sql('gamestable', conn, if_exists='replace', index = False)
curr.execute('''
SELECT * FROM gamestable limit 5
 ''')
for row in curr.fetchall():
 print (row)
# Out:
# (81, 1, 2015, '2015-08-08 15:45:00', 89, 82, 1, 0, 0.2843, 0.3999, 0.3158, 1, 0, 1.65, 4.0, 6.0, 1.65, 4.0, 5.5, 1.65, 3.6, 5.1, 1.65, 4.09, 5.9, 1.62, 3.6, 6.0, 1.67, 4.0, 5.75, 1.64, 4.07, 6.04)
# (82, 1, 2015, '2015-08-08 18:00:00', 73, 71, 0, 1, 0.3574, 0.35, 0.2926, 0, 0, 2.0, 3.6, 4.0, 2.0, 3.3, 3.7, 2.1, 3.3, 3.3, 1.95, 3.65, 4.27, 1.91, 3.5, 4.0, 2.0, 3.5, 4.2, 1.82, 3.88, 4.7)
# (83, 1, 2015, '2015-08-08 18:00:00', 72, 90, 2, 2, 0.2988, 0.4337, 0.2675, 0, 1, 1.7, 3.9, 5.5, 1.7, 3.5, 5.0, 1.7, 3.6, 4.7, 1.7, 3.95, 5.62, 1.73, 3.5, 5.0, 1.73, 3.9, 5.4, 1.75, 3.76, 5.44)
# (84, 1, 2015, '2015-08-08 18:00:00', 75, 77, 4, 2, 0.6422, 0.2057, 0.1521, 3, 0, 1.95, 3.5, 4.33, 2.0, 3.3, 3.75, 2.0, 3.3, 3.6, 1.99, 3.48, 4.34, 2.0, 3.1, 2.7, 2.0, 3.4, 4.33, 1.79, 3.74, 5.1)
# (85, 1, 2015, '2015-08-08 18:00:00', 79, 78, 1, 3, 0.1461, 0.2159, 0.638, 0, 1, 2.55, 3.3, 3.0, 2.6, 3.2, 2.7, 2.4, 3.2, 2.85, 2.52, 3.35, 3.08, 2.6, 3.1, 2.88, 2.6, 3.25, 3.0, 2.46, 3.39, 3.14)

# %%
shots=pd.read_csv('shots.csv', encoding = 'ISO-8859-1')
shots.to_sql('shotstable', conn, if_exists='replace', index = False)
curr.execute('''
SELECT * FROM shotstable limit 5
 ''')
for row in curr.fetchall():
 print (row)
# Out:
# (81, 554, None, 27, 'DirectFreekick', 'Standard', 'LeftFoot', 'BlockedShot', 0.104346722364426, 0.794000015258789, 0.420999984741211)
# (81, 555, 631.0, 27, 'SetPiece', 'Pass', 'RightFoot', 'BlockedShot', 0.064342200756073, 0.86, 0.627000007629395)
# (81, 554, 629.0, 35, 'OpenPlay', 'Pass', 'LeftFoot', 'BlockedShot', 0.0571568161249161, 0.843000030517578, 0.332999992370605)
# (81, 554, None, 35, 'OpenPlay', 'Tackle', 'LeftFoot', 'MissedShots', 0.0921413898468018, 0.848000030517578, 0.532999992370605)
# (81, 555, 654.0, 40, 'OpenPlay', 'BallRecovery', 'RightFoot', 'BlockedShot', 0.0357420146465302, 0.811999969482422, 0.706999969482422)

# %%
curr.execute('''
SELECT * FROM shotstable JOIN playertable ON shotstable.shooterID=playertable.playerID limit 5
 ''')
for row in curr.fetchall():
 print(row)
# Out:
# (81, 554, None, 27, 'DirectFreekick', 'Standard', 'LeftFoot', 'BlockedShot', 0.104346722364426, 0.794000015258789, 0.420999984741211, 554, 'Juan Mata')
# (81, 555, 631.0, 27, 'SetPiece', 'Pass', 'RightFoot', 'BlockedShot', 0.064342200756073, 0.86, 0.627000007629395, 555, 'Memphis Depay')
# (81, 554, 629.0, 35, 'OpenPlay', 'Pass', 'LeftFoot', 'BlockedShot', 0.0571568161249161, 0.843000030517578, 0.332999992370605, 554, 'Juan Mata')
# (81, 554, None, 35, 'OpenPlay', 'Tackle', 'LeftFoot', 'MissedShots', 0.0921413898468018, 0.848000030517578, 0.532999992370605, 554, 'Juan Mata')
# (81, 555, 654.0, 40, 'OpenPlay', 'BallRecovery', 'RightFoot', 'BlockedShot', 0.0357420146465302, 0.811999969482422, 0.706999969482422, 555, 'Memphis Depay')

# %%
from rpy2 import robjects

robjects.r('''
my_variable<-512
print(my_variable+12)
''')
# Out:
# [1] 524

# %%
robjects.r('''
players<-read.csv('players.csv')
print(head(players))
''')
# Out:
#   playerID                name
# 1      560       Sergio Romero
# 2      557      Matteo Darmian
# 3      548         Daley Blind
# 4      628      Chris Smalling
# 5     1006           Luke Shaw
# 6      551 Morgan Schneiderlin

# %%
robjects.r('''
shots<-read.csv('shots.csv')
print(head(shots))
''')
# Out:
#   gameID shooterID assisterID minute      situation   lastAction  shotType
# 1     81       554         NA     27 DirectFreekick     Standard  LeftFoot
# 2     81       555        631     27       SetPiece         Pass RightFoot
# 3     81       554        629     35       OpenPlay         Pass  LeftFoot
# 4     81       554         NA     35       OpenPlay       Tackle  LeftFoot
# 5     81       555        654     40       OpenPlay BallRecovery RightFoot
# 6     81       555        629     49       OpenPlay         Pass  LeftFoot
#    shotResult      xGoal positionX positionY
# 1 BlockedShot 0.10434672     0.794     0.421
# 2 BlockedShot 0.06434220     0.860     0.627
# 3 BlockedShot 0.05715682     0.843     0.333
# 4 MissedShots 0.09214139     0.848     0.533
# 5 BlockedShot 0.03574201     0.812     0.707
# 6 MissedShots 0.02122466     0.725     0.545

# %%
robjects.r('''
print(head(shots$minute))
print(head(shots$positionX))
''')
# Out:
# [1] 27 27 35 35 40 49
# [1] 0.794 0.860 0.843 0.848 0.812 0.725

# %%
robjects.r('''
shot_location_model <- lm(positionX~minute,data=shots)
print(summary(shot_location_model))
''')
# Out:
# Call:
# lm(formula = positionX ~ minute, data = shots)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.84262 -0.06312  0.01885  0.06443  0.15716
#
# Coefficients:
#              Estimate Std. Error  t value Pr(>|t|)
# (Intercept) 8.414e-01  3.291e-04 2556.513   <2e-16 ***
# minute      5.251e-05  5.944e-06    8.835   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09 on 324541 degrees of freedom
# Multiple R-squared:  0.0002404,	Adjusted R-squared:  0.0002374
# F-statistic: 78.05 on 1 and 324541 DF,  p-value: < 2.2e-16

# %%
robjects.r('''
png(filename='the_plot_chapter11.png')
plot(shots$minute,shots$positionX)
abline(shot_location_model)
dev.off()
''')
# Out:
# <rpy2.robjects.vectors.IntVector object at 0x7c59fb36b190> [13]
# R classes: ('integer',)
# [1]

# %% [markdown]
# Ch 11 Summary:
#
# This chapter provides an introduction to the SQL and R languages and gives instructions on how to implement them in a Python script.
#
# After downloading some csv files related to this chapter’s business scenario, we read the files in Python so we have a base for comparison later on. We then pivot to looking at SQL syntax. SQL commands are pretty easy to understand, even for someone without a computer science background. The chapter shows us how to import the sqlite3 package and connect it to our sample data. Before running queries we have to add the data to our database as tables. Then, we are able to run SQL queries by first using curr.execute() and adding the command inside the parentheses. The book walks through the printing of the data like how we did in the original Python script.
#
# The chapter highlights some characteristics and tools specific to SQL. Included are certain operators, such as WHERE or AND, and character uses like % and *. Another speciality of SQL is easily joining together tables to compare data easier.
#
# Next, the chapter moves on to discussing R. R is far more similar to Python than SQL was, so the syntax is less foreign to us. A notable difference is defining variables with arrows instead of equal signs. Similar to what we did with SQL, we import a package (rpy2) and write our R code inside a function (robjects.r()). We follow the same first step of printing out some of the data and getting a look at our columns. Along the way, we get a peek of some R syntax, like the use of $ to refer to columns.
#
# We wrap up our section on R with an overview of how to do linear regression and plot data in a graph. R has a command called lm() that we can use to calculate our regression and print out relevant information like summary stats on the residuals, the coefficients, and our estimated errors and R-squared values. We can plot this regression and the data points in four short lines of R code. We use the png() function to open a file where the graph will be saved and finish with dev.off() to tell R that the plot is done and can be saved.
#
# The chapter ends by summarizing some other programming languages and softwares that may be useful for data scientists to be familiar with: C++, Scala, Julia, JavaScript, MATLAB, SAS, Stata, and SPSS. It also references some math and computing skills that are related to data science: linear algebra, Bayesian statistics, nonparametric statistics, and more.
