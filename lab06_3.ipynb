# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhias-a11y/colab/blob/main/lab06_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # part 3

# %%
from itertools import product
from collections import defaultdict

def generate_coin_sample_space(num_flips):
  weighted_sample_space = defaultdict(int)
  for coin_flips in product(['Heads', 'Tails'], repeat=num_flips):
    heads_count = len([outcome for outcome in coin_flips if outcome == 'Heads'])
    weighted_sample_space[heads_count] += 1
  return weighted_sample_space

weighted_sample_space = generate_coin_sample_space(10)
weighted_sample_space_20_flips = generate_coin_sample_space(20)
weighted_sample_space_20_flips
# Out:
# defaultdict(int,
#             {20: 1,
#              19: 20,
#              18: 190,
#              17: 1140,
#              16: 4845,
#              15: 15504,
#              14: 38760,
#              13: 77520,
#              12: 125970,
#              11: 167960,
#              10: 184756,
#              9: 167960,
#              8: 125970,
#              7: 77520,
#              6: 38760,
#              5: 15504,
#              4: 4845,
#              3: 1140,
#              2: 190,
#              1: 20,
#              0: 1})

# %%
x_20_flips = list(weighted_sample_space_20_flips.keys())
y_20_flips = [weighted_sample_space_20_flips[key] for key in x_20_flips]
sample_space_size = sum(weighted_sample_space_20_flips.values())
prob_x_20_flips = [value / sample_space_size for value in y_20_flips]

# %%
import matplotlib.pyplot as plt
x_10_flips = list(weighted_sample_space.keys())
y_10_flips = [weighted_sample_space[key] for key in x_10_flips]
sample_space_size = sum(weighted_sample_space.values())
prob_x_10_flips = [value/sample_space_size for value in y_10_flips]

# %%
import matplotlib.pyplot as plt

plt.plot(x_10_flips, prob_x_10_flips)
plt.scatter(x_10_flips, prob_x_10_flips)
plt.plot(x_20_flips, prob_x_20_flips, color = 'black', linestyle = "--", label = "B: 20 coin-flips")
plt.scatter(x_20_flips, prob_x_20_flips, color='k', marker='x')
plt.xlabel('Number of heads')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %%
def is_in_interval(number, minimum, maximum):
  return minimum <= number <= maximum

plt.plot(x_10_flips, prob_x_10_flips, label = 'A: 1- coin-flips')
plt.plot(x_20_flips, prob_x_20_flips, color = 'k', linestyle=':', label = 'B: 20 coin-flips')
where_10= [not is_in_interval(value, 3, 7) for value in x_10_flips]
plt.fill_between(x_10_flips, prob_x_10_flips, where=where_10)
where_20= [not is_in_interval(value, 5, 15) for value in x_20_flips]
plt.fill_between(x_20_flips, prob_x_20_flips, where=where_20)
plt.legend()
plt.show()

# %%
x_10_frequencies = [head_count /10 for head_count in x_10_flips]
x_20_frequencies = [head_count /20 for head_count in x_20_flips]
plt.plot(x_10_frequencies, prob_x_10_flips, label='A: 10 coin-flips')
plt.plot(x_20_frequencies, prob_x_20_flips, color='k', linestyle=':',
label='B: 20 coin-flips')
plt.legend()
plt.xlabel('Head-Frequency')
plt.ylabel('Probability')
plt.show()

# %%
relative_likelihood_10 = [10*prob for prob in prob_x_10_flips]
relative_likelihood_20 = [20*prob for prob in prob_x_20_flips]

plt.plot(x_10_frequencies, relative_likelihood_10, label='A: 10 coin-flips')
plt.plot(x_20_frequencies, relative_likelihood_20, color='k',linestyle=':', label='B: 20 coin-flips')

plt.fill_between(x_10_frequencies, relative_likelihood_10, where=where_10)
plt.fill_between(x_20_frequencies, relative_likelihood_20, where=where_20)

plt.xlabel("Frequency of Heads")
plt.ylabel("Relative Likelihood")
plt.legend()
plt.show()

# %% [markdown]
# How do we answer the question at the end of Chapter 1 with Matplotlib?
# q: "why does the probability of
# observing an extreme result decrease as the coin is flipped more times?"
#
# Matplotlib shows us that when we increase the number of flips to 20, the likelihood of getting an exactly even split between heads and tails becomes higher. This is a part of a phenomenon known as regression to the mean. The area beneath the curve represents the probability of the result landing in that result interval. The final plot demonstrates this by showing us that the area below the curve for the extreme possibilities (very low or very high number of heads) is smaller for the 20 flips graph than the 10 flips graph.
