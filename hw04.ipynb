# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhias-a11y/colab/blob/main/hw04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BstNode:
 def __init__(self, key):
  self.key = key
  self.right = None
  self.left = None

 def display(self):
  lines,*_ = self._display_aux()
  for line in lines:
   print(line)

 def _display_aux(self):
 # No child.
  if self.right is None and self.left is None:
    line = '%s' % self.key
    width = len(line)
    height = 1
    middle = width // 2
    return [line], width, height, middle
 # Only left child.
  if self.right is None:
    lines, n, p, x = self.left._display_aux()
    s = '%s' % self.key
    u = len(s)
    first_line = (x + 1) * ' ' + (n - x - 1) * '_' + s
    second_line = x * ' ' + '/' + (n - x - 1 + u) * ' ';
    shifted_lines = [line + u * ' ' for line in lines]
    return [first_line, second_line] + shifted_lines, n + u, p + 2, n + u // 2
 # Only right child.
  if self.left is None:
    lines, n, p, x = self.right._display_aux()
    s = '%s' % self.key
    u = len(s)
    first_line = s + x * '_' + (n - x) * ' '
    second_line = (u + x) * ' ' + '\\' + (n - x - 1) * ' '
    shifted_lines = [u * ' ' + line for line in lines]
    return [first_line, second_line] + shifted_lines, n + u, p + 2, u // 2
 # Two children.
  left, n, p, x = self.left._display_aux()
  right, m, q, y = self.right._display_aux()
  s = '%s' % self.key
  u = len(s)
  first_line = (x + 1) * ' ' + (n - x - 1) * '_' + s + y * '_' + (m - y) * ' '
  second_line = x * ' ' + '/' + (n - x - 1 + u + y) * ' ' + '\\' + (m - y - 1) * ' '
  if p < q:
    left += [n * ' '] * (q - p)
  elif q < p:
    right += [m * ' '] * (p - q)
  zipped_lines = zip(left, right)
  lines = [first_line, second_line] + [a + u * ' ' + b for a, b in zipped_lines]
  return lines, n + u + m, max(p,q) + 2, n + u // 2

a = BstNode(3)
a.left = BstNode(5)
a.left.right = BstNode(1)
a.display()
print("------------")
b = BstNode(7)
b.left = BstNode(4)
a.right = b
a.display()
print("------------")
b = BstNode(2)
b.right = a.right
a.right = b
a.display()

class BST(BstNode):
 def __init__(self, name):
  super().__init__(name)

 def insert(self, value):
  if self.key == value:
    return
  elif self.key < value:
    if self.right == None:
      self.right = BST(value)
    else:
      self.right.insert(value)
  else:
    if self.left == None:
      self.left = BST(value)
    else:
      self.left.insert(value)

 def find(self, value):
  if value == self.key:
    return True
  elif value > self.key:
    if self.right == None:
      return False
    else:
      return self.right.find(value)
  else:
    if self.left ==None:
      return False
    else:
      return self.left.find(value)

 def largestValue(self):
  if self.right == None:
    return self.key
  else:
    return self.right.largestValue()

 def remove(self, value):
  if self.key == value:
   if self.right ==None:
    return self.left
   if self.left ==None:
    return self.right
   else:
    num = self.left.largestValue()
    self.key = num
    self.left = self.left.remove(num)
  elif self.key < value:
   if self.right:
    self.right = self.right.remove(value)
  else:
   if self.left:
    self.left = self.left.remove(value)
  return self

print()
tree = BST(7)
for num in [6,1,5,2,4,3]:
  tree.insert(num)
tree.display()
tree.find(1)
tree.remove(4)
tree.insert(9)
tree.display()
# Out:
#  _3
# /
# 5
#  \
#  1
# ------------
#  _3_
# /   \
# 5   7
#  \ /
#  1 4
# ------------
#  _3
# /  \
# 5  2_
#  \   \
#  1   7
#     /
#     4
#
#       7
#      /
#  ____6
# /
# 1___
#     \
#   __5
#  /
#  2_
#    \
#    4
#   /
#   3
#      7
#     / \
#  ___6 9
# /
# 1__
#    \
#   _5
#  /
#  2
#   \
#   3

# %% [markdown]
# The section of code provided in problem 4 of the spring 2023 midterm implements the BSTNode class. The code first creates a three node tree (3,5,1) named "a" and then connects a new branch(7,4) through another BSTNode implementation "b". The code then redefines "b" to have the root 2 before reestablishing the (7,4) branch and connecting it all to the original "a" tree. It is important to note that this BSTNode implementation does not insert new numbers into the tree where they should be placed under the rules of a binary search tree. For example, the original "a" tree reads horizontally as 5,1,3 rather than 1,3,5.
